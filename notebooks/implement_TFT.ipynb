# %%
import sys
from pathlib import Path

sys.path.append(str(Path().absolute().parent))

# %%
import pytorch_lightning as pl
import matplotlib.pyplot as plt
import torch

import seaborn as sns

import pandas as pd
from pathlib import Path


from src.data_models.caravanify import Caravanify, CaravanifyConfig

from src.data_models.datamodule import HydroDataModule

from sklearn.pipeline import Pipeline

from src.preprocessing.grouped import GroupedTransformer
# from src.preprocessing.log_scale import LogTransformer
from src.preprocessing.standard_scale import StandardScaleTransformer

from src.model_evaluation.evaluators import TSForecastEvaluator
from src.model_evaluation.visualization import plot_basin_map, plot_metric_boxplot, plot_metric_cdf, plot_rolling_forecast
from src.models.tft import TFTConfig, LitTFT

# %% [markdown]
# ---

# %%
config = CaravanifyConfig(
    attributes_dir="/Users/cooper/Desktop/CAMELS-CH/data/CARAVANIFY/CA/post_processed/attributes",
    timeseries_dir="/Users/cooper/Desktop/CAMELS-CH/data/CARAVANIFY/CA/post_processed/timeseries/csv",
    shapefile_dir="/Users/cooper/Desktop/CAMELS-CH/data/CARAVANIFY/CA/post_processed/shapefiles",
    human_influence_path="/Users/cooper/Desktop/CAMELS-CH/src/human_influence_index/results/human_influence_classification.csv",
    gauge_id_prefix="CA",
    use_hydroatlas_attributes=True,
    use_caravan_attributes=True,
    use_other_attributes=True,
)


caravan = Caravanify(config)
ids_for_training = caravan.get_all_gauge_ids()[:10]

path_to_hii = "/Users/cooper/Desktop/CAMELS-CH/src/human_influence_index/results/human_influence_classification.csv"

ids_for_training, _ = caravan.filter_gauge_ids_by_human_influence(
    ids_for_training, ["Low", "Medium"]
)

caravan.load_stations(ids_for_training)
static_data = caravan.get_static_attributes()
ts_data = caravan.get_time_series()
# Out:
# Original gauge_ids: 10
# Filtered gauge_ids: 10

# %%
ts_columns = [
    "potential_evaporation_sum_FAO_PENMAN_MONTEITH",
    "streamflow",
    "temperature_2m_mean",
    "total_precipitation_sum",
]

ts_columns_to_keep = ts_columns + ["gauge_id", "date"]
ts_data = ts_data[ts_columns_to_keep]

# %%
static_columns = [
    "p_mean",
    "area",
    "ele_mt_sav",
    "high_prec_dur",
    "frac_snow",
    "high_prec_freq",
    "slp_dg_sav",
    "cly_pc_sav",
    "aridity_ERA5_LAND",
    "aridity_FAO_PM",
]

static_columns_to_keep = static_columns + ["gauge_id"]

static_data = static_data[static_columns_to_keep]

# %%
forcing_features = [
    col for col in ts_columns if col not in ["gauge_id", "date", "streamflow"]
]

target_feature = "streamflow"

# %% [markdown]
# ---

# %%
feature_pipeline = Pipeline(
    [
        # ("log", LogTransformer(columns=dynamic_feature_cols)),
        ("scaler", StandardScaleTransformer(columns=forcing_features)),
    ]
)

# Target pipeline: grouped by basin with log + scale
target_pipeline = GroupedTransformer(
    Pipeline(
        [
            # ("log", LogTransformer(columns=target_cols)),
            ("scaler", StandardScaleTransformer(columns=[target_feature])),
        ]
    ),
    columns=[target_feature],
    group_identifier="gauge_id",
    n_jobs=-1,
)

# Static feature pipeline: just scaling
static_pipeline = Pipeline(
    [("scaler", StandardScaleTransformer(columns=static_columns))]
)

# Define preprocessing configurations
preprocessing_configs = {
    "features": {"pipeline": feature_pipeline, "columns": ts_columns},
    "target": {"pipeline": target_pipeline, "columns": [target_feature]},
    "static_features": {"pipeline": static_pipeline, "columns": static_columns},
}

# %% [markdown]
# ---

# %%
output_length = 10
input_length = 40

data_module = HydroDataModule(
    time_series_df=ts_data,
    static_df=static_data,
    group_identifier="gauge_id",
    preprocessing_config=preprocessing_configs,
    batch_size=256,
    input_length=input_length,
    output_length=output_length,
    num_workers=4,
    features=ts_columns,
    static_features=static_columns,
    target="streamflow",
    train_prop=0.5,
    val_prop=0.25,
    test_prop=0.25,
    domain_id="CH",
    use_proportional_split=True,
    max_imputation_gap_size=2,
    
)

data_module.prepare_data()
data_module.setup(stage="fit")
# Out:
# Original basins: 10
# Retained basins: 8
# Domain CH (source): Created 32968 valid sequences from 8 catchments
# Domain CH (source): Created 16284 valid sequences from 8 catchments

# %% [markdown]
# ---

# %%
config = TFTConfig(
    input_len=input_length,
    output_len=output_length,
    input_size=len(ts_columns),
    static_size=len(static_columns),
    future_input_size=len(ts_columns) - 1,
    hidden_size=16,
    dropout=0.1,
    learning_rate=1e-3,
    # TFT specific parameters
    lstm_layers=2,
    num_attention_heads=4,
    attn_dropout=0.1,
    scheduler_patience=3,
    scheduler_factor=0.5,
)

model = LitTFT(config)

# %%
model
# Out:
# LitTFT(
#   (mse_criterion): MSELoss()
#   (model): TemporalFusionTransformer(
#     (target_input_proj): Linear(in_features=1, out_features=16, bias=True)
#     (past_feat_proj): Linear(in_features=3, out_features=16, bias=True)
#     (future_feat_proj): Linear(in_features=3, out_features=16, bias=True)
#     (static_feat_proj): Linear(in_features=10, out_features=16, bias=True)
#     (past_vsn): VariableSelectionNetwork(
#       (selection_network): GatedResidualNetwork(
#         (skip_layer): Linear(in_features=32, out_features=2, bias=True)
#         (fc1): Linear(in_features=32, out_features=16, bias=True)
#         (elu): ELU(alpha=1.0)
#         (context_layer): Linear(in_features=16, out_features=16, bias=False)
#         (fc2): Linear(in_features=16, out_features=2, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (gate): GLU(
#           (fc1): Linear(in_features=2, out_features=2, bias=True)
#           (fc2): Linear(in_features=2, out_features=2, bias=True)
#           (sigmoid): Sigmoid()
#         )
#         (layer_norm): LayerNorm((2,), eps=1e-05, elementwise_affine=True)
#       )
#       (var_processors): ModuleList(
#         (0-1): 2 x GatedResidualNetwork(
#           (fc1): Linear(in_features=16, out_features=16, bias=True)
#           (elu): ELU(alpha=1.0)
#           (fc2): Linear(in_features=16, out_features=16, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (gate): GLU(
#             (fc1): Linear(in_features=16, out_features=16, bias=True)
#             (fc2): Linear(in_features=16, out_features=16, bias=True)
#             (sigmoid): Sigmoid()
#           )
#           (layer_norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (softmax): Softmax(dim=-1)
#     )
#     (future_vsn): VariableSelectionNetwork(
#       (selection_network): GatedResidualNetwork(
#         (skip_layer): Linear(in_features=16, out_features=1, bias=True)
#         (fc1): Linear(in_features=16, out_features=16, bias=True)
#         (elu): ELU(alpha=1.0)
#         (context_layer): Linear(in_features=16, out_features=16, bias=False)
#         (fc2): Linear(in_features=16, out_features=1, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (gate): GLU(
#           (fc1): Linear(in_features=1, out_features=1, bias=True)
#           (fc2): Linear(in_features=1, out_features=1, bias=True)
#           (sigmoid): Sigmoid()
#         )
#         (layer_norm): LayerNorm((1,), eps=1e-05, elementwise_affine=True)
#       )
#       (var_processors): ModuleList(
#         (0): GatedResidualNetwork(
#           (fc1): Linear(in_features=16, out_features=16, bias=True)
#           (elu): ELU(alpha=1.0)
#           (fc2): Linear(in_features=16, out_features=16, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (gate): GLU(
#             (fc1): Linear(in_features=16, out_features=16, bias=True)
#             (fc2): Linear(in_features=16, out_features=16, bias=True)
#             (sigmoid): Sigmoid()
#           )
#           (layer_norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (softmax): Softmax(dim=-1)
#     )
#     (static_encoder): StaticCovariateEncoder(
#       (grn_vs): GatedResidualNetwork(
#         (fc1): Linear(in_features=16, out_features=16, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=16, out_features=16, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (gate): GLU(
#           (fc1): Linear(in_features=16, out_features=16, bias=True)
#           (fc2): Linear(in_features=16, out_features=16, bias=True)
#           (sigmoid): Sigmoid()
#         )
#         (layer_norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       )
#       (grn_se): GatedResidualNetwork(
#         (fc1): Linear(in_features=16, out_features=16, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=16, out_features=16, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (gate): GLU(
#           (fc1): Linear(in_features=16, out_features=16, bias=True)
#           (fc2): Linear(in_features=16, out_features=16, bias=True)
#           (sigmoid): Sigmoid()
#         )
#         (layer_norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       )
#       (grn_h): GatedResidualNetwork(
#         (fc1): Linear(in_features=16, out_features=16, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=16, out_features=16, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (gate): GLU(
#           (fc1): Linear(in_features=16, out_features=16, bias=True)
#           (fc2): Linear(in_features=16, out_features=16, bias=True)
#           (sigmoid): Sigmoid()
#         )
#         (layer_norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       )
#       (grn_c): GatedResidualNetwork(
#         (fc1): Linear(in_features=16, out_features=16, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=16, out_features=16, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (gate): GLU(
#           (fc1): Linear(in_features=16, out_features=16, bias=True)
#           (fc2): Linear(in_features=16, out_features=16, bias=True)
#           (sigmoid): Sigmoid()
#         )
#         (layer_norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (lstm_encoder): LSTM(16, 16, num_layers=2, batch_first=True, dropout=0.1)
#     (lstm_decoder): LSTM(16, 16, num_layers=2, batch_first=True, dropout=0.1)
#     (post_lstm_gate): GLU(
#       (fc1): Linear(in_features=16, out_features=16, bias=True)
#       (fc2): Linear(in_features=16, out_features=16, bias=True)
#       (sigmoid): Sigmoid()
#     )
#     (post_lstm_norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#     (static_enrichment): GatedResidualNetwork(
#       (fc1): Linear(in_features=16, out_features=16, bias=True)
#       (elu): ELU(alpha=1.0)
#       (context_layer): Linear(in_features=16, out_features=16, bias=False)
#       (fc2): Linear(in_features=16, out_features=16, bias=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (gate): GLU(
#         (fc1): Linear(in_features=16, out_features=16, bias=True)
#         (fc2): Linear(in_features=16, out_features=16, bias=True)
#         (sigmoid): Sigmoid()
#       )
#       (layer_norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#     )
#     (attention): InterpretableMultiHeadAttention(
#       (q_projections): ModuleList(
#         (0-3): 4 x Linear(in_features=16, out_features=4, bias=False)
#       )
#       (k_projections): ModuleList(
#         (0-3): 4 x Linear(in_features=16, out_features=4, bias=False)
#       )
#       (v_projection): Linear(in_features=16, out_features=4, bias=False)
#       (output_projection): Linear(in_features=4, out_features=16, bias=True)
#       (attn_dropout): Dropout(p=0.1, inplace=False)
#     )
#     (post_attn_gate): GLU(
#       (fc1): Linear(in_features=16, out_features=16, bias=True)
#       (fc2): Linear(in_features=16, out_features=16, bias=True)
#       (sigmoid): Sigmoid()
#     )
#     (post_attn_norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#     (pos_wise_ff): GatedResidualNetwork(
#       (fc1): Linear(in_features=16, out_features=16, bias=True)
#       (elu): ELU(alpha=1.0)
#       (fc2): Linear(in_features=16, out_features=16, bias=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (gate): GLU(
#         (fc1): Linear(in_features=16, out_features=16, bias=True)
#         (fc2): Linear(in_features=16, out_features=16, bias=True)
#         (sigmoid): Sigmoid()
#       )
#       (layer_norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#     )
#     (pre_output_gate): GLU(
#       (fc1): Linear(in_features=16, out_features=16, bias=True)
#       (fc2): Linear(in_features=16, out_features=16, bias=True)
#       (sigmoid): Sigmoid()
#     )
#     (pre_output_norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#     (output_layer): Linear(in_features=16, out_features=1, bias=True)
#   )
#   (quantile_loss): QuantileLoss()
# )

# %%
trainer = pl.Trainer(
    max_epochs=1,
    accelerator="cpu",
    devices=1,
)

# Train the model
torch.autograd.set_detect_anomaly(True)
trainer.fit(model, data_module)
# Out:
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# /Users/cooper/Desktop/CAMELS-CH/.venv/lib/python3.12/site-packages/pytorch_lightning/trainer/setup.py:177: GPU available but not used. You can set it by doing `Trainer(accelerator='gpu')`.
# Original basins: 10
# Retained basins: 8
#   | Name          | Type                      | Params | Mode
# --------------------------------------------------------------------
# 0 | mse_criterion | MSELoss                   | 0      | train
# 1 | model         | TemporalFusionTransformer | 23.2 K | train
# 2 | quantile_loss | QuantileLoss              | 0      | train
# --------------------------------------------------------------------
# 23.2 K    Trainable params
# 0         Non-trainable params
# 23.2 K    Total params
# 0.093     Total estimated model params size (MB)
# 161       Modules in train mode
# 0         Modules in eval mode
# Domain CH (source): Created 32968 valid sequences from 8 catchments
# Domain CH (source): Created 16284 valid sequences from 8 catchments
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=1` reached.

# %%
models_and_datamodules = {
    "TFT": (model, data_module),
}

evaluator = TSForecastEvaluator(
    horizons=list(range(1, 11)),
    models_and_datamodules=models_and_datamodules,  
    trainer_kwargs={"accelerator": "cpu", "devices": 1},
)

# %%
results = evaluator.test_models()

# %%
overall_summary = evaluator.summarize_metrics(results["TFT"]["metrics"])

def plot_metric_summary(
    summary_df: pd.DataFrame, metric: str, per_basin: bool = False, figsize=(10, 6)
):
    plt.figure(figsize=figsize)

    if per_basin:
        df_plot = summary_df[metric].unstack(level=0)

        # Sort basins based on first horizon values
        first_horizon_values = df_plot.iloc[0]
        sorted_basins = first_horizon_values.sort_values(ascending=False).index
        df_plot = df_plot[sorted_basins]

        sns.barplot(
            data=df_plot.melt(ignore_index=False).reset_index(),
            x="horizon",
            y="value",
            hue="basin_id",
            palette="Blues",
        )
        plt.title(f"{metric} by Basin and Horizon")
        plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left", title="Basin ID")

    else:
        ax = sns.barplot(x=summary_df.index, y=summary_df[metric], color="steelblue")
        plt.title(f"Overall {metric} by Horizon")

        for i, v in enumerate(summary_df[metric]):
            ax.text(i, v, f"{v:.2f}", ha="center", va="bottom")

    plt.xlabel("Forecast Horizon")
    plt.ylabel(metric)
    plt.tight_layout()
    sns.despine()
    plt.show()


 # Plot overall NSE
plot_metric_summary(
    overall_summary,
    metric="NSE",
    per_basin=False,
    figsize=(10, 6),
)

# %%
plot_rolling_forecast(
    results["TFT"]["df"],
    horizon=10, 
    group_identifier="CA_15044"
)

# %%
plot_basin_map(
    results,
    'TFT',
    caravanify_instance=caravan,

)

# %%
plot_metric_boxplot(
    results,
    ['TFT'],
    metric='NSE',
)
